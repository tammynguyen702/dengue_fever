# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
dengue_features_train=pd.read_csv('dengue_features_train.csv')
dengue_labels_train= pd.read_csv('dengue_labels_train.csv')

# dengue_features_train=pd.read_csv('/content/gdrive/My Drive/Foundation Of DataScience/Final Project/Final Project/dengue_features_train.csv')
# dengue_labels_train=pd.read_csv('/content/gdrive/My Drive/Foundation Of DataScience/Final Project/Final Project/dengue_labels_train.csv')
dengue_features_train.head(5)
# Out:
#   city  year  ...  station_min_temp_c station_precip_mm
# 0   sj  1990  ...                20.0              16.0
# 1   sj  1990  ...                22.2               8.6
# 2   sj  1990  ...                22.8              41.4
# 3   sj  1990  ...                23.3               4.0
# 4   sj  1990  ...                23.9               5.8
#
# [5 rows x 24 columns]

# %%
dengue_labels_train.head(5)
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
# Join the training features and Labale to analysing them

new_train_set = pd.merge(dengue_features_train,dengue_labels_train, how='left', left_on =['city','year','weekofyear'], right_on=['city','year','weekofyear'])

# %%
type(new_train_set)
# Out:
# pandas.core.frame.DataFrame

# %%
new_train_set.describe()
# Out:
#               year   weekofyear  ...  station_precip_mm  total_cases
# count  1456.000000  1456.000000  ...        1434.000000  1456.000000
# mean   2001.031593    26.503434  ...          39.326360    24.675137
# std       5.408314    15.019437  ...          47.455314    43.596000
# min    1990.000000     1.000000  ...           0.000000     0.000000
# 25%    1997.000000    13.750000  ...           8.700000     5.000000
# 50%    2002.000000    26.500000  ...          23.850000    12.000000
# 75%    2005.000000    39.250000  ...          53.900000    28.000000
# max    2010.000000    53.000000  ...         543.300000   461.000000
#
# [8 rows x 23 columns]

# %%
# check the columns name
new_train_set.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'total_cases'],
#       dtype='object')

# %%
corr_matrix = new_train_set.corr()
corr_matrix["total_cases"].sort_values(ascending=False)
# Out:
# total_cases                              1.000000
# reanalysis_min_air_temp_k                0.325252
# station_min_temp_c                       0.267109
# reanalysis_air_temp_k                    0.264952
# weekofyear                               0.216452
# reanalysis_avg_temp_k                    0.151637
# reanalysis_dew_point_temp_k              0.142531
# reanalysis_specific_humidity_g_per_kg    0.129861
# station_avg_temp_c                       0.116109
# reanalysis_precip_amt_kg_per_m2         -0.010031
# precipitation_amt_mm                    -0.038740
# reanalysis_sat_precip_amt_mm            -0.038740
# station_max_temp_c                      -0.039219
# station_precip_mm                       -0.074374
# reanalysis_relative_humidity_percent    -0.132452
# ndvi_se                                 -0.168612
# reanalysis_max_air_temp_k               -0.191345
# ndvi_sw                                 -0.196461
# ndvi_nw                                 -0.202235
# station_diur_temp_rng_c                 -0.237844
# ndvi_ne                                 -0.241376
# reanalysis_tdtr_k                       -0.278483
# year                                    -0.306806
# Name: total_cases, dtype: float64

# %%
# test_df=pd.read_csv('dengue_features_test.csv')

# %%
#remove duplcates, subset, keep, etc.
new_train_set.drop_duplicates()
# Out:
#      city  year  weekofyear  ... station_min_temp_c  station_precip_mm  total_cases
# 0      sj  1990          18  ...               20.0               16.0            4
# 1      sj  1990          19  ...               22.2                8.6            5
# 2      sj  1990          20  ...               22.8               41.4            4
# 3      sj  1990          21  ...               23.3                4.0            3
# 4      sj  1990          22  ...               23.9                5.8            6
# ...   ...   ...         ...  ...                ...                ...          ...
# 1451   iq  2010          21  ...               22.4               27.0            5
# 1452   iq  2010          22  ...               21.7               36.6            8
# 1453   iq  2010          23  ...               19.2                7.4            1
# 1454   iq  2010          24  ...               21.0               16.0            1
# 1455   iq  2010          25  ...               22.2               20.4            4
#
# [1456 rows x 25 columns]

# %%
# replacing sj with 1 and 


# dengue_features_train['city']=(dengue_features_train['city']=='sj').astype(int)

# %%
new_train_set.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# total_cases                                0
# dtype: int64

# %%
# Deal with NULL values
# I used avarage value for temperater feature to fill the NULL values

# replacing na values with previeus value  with limitation of 3 days 
new_train_set['reanalysis_air_temp_k'].fillna(method='ffill',limit=3,inplace=True)
new_train_set['reanalysis_tdtr_k'].fillna(method='ffill',limit=3,inplace=True)
new_train_set['station_diur_temp_rng_c'].fillna(method='ffill',inplace=True)
new_train_set['ndvi_nw'].fillna(method='ffill',limit=3,inplace=True)
new_train_set['ndvi_se'].fillna(method='ffill',limit=3,inplace=True)
new_train_set['ndvi_sw'].fillna(method='ffill',limit=3,inplace=True)
new_train_set['ndvi_ne'].fillna(method='ffill',limit=3,inplace=True)


# replacing na values with average value
new_train_set['reanalysis_avg_temp_k'].fillna(new_train_set['reanalysis_avg_temp_k'].mean(),inplace=True)
new_train_set['reanalysis_dew_point_temp_k'].fillna(new_train_set['reanalysis_dew_point_temp_k'].mean(),inplace=True)
new_train_set['reanalysis_max_air_temp_k'].fillna(new_train_set['reanalysis_max_air_temp_k'].mean(),inplace=True)
new_train_set['reanalysis_min_air_temp_k'].fillna(new_train_set['reanalysis_min_air_temp_k'].mean(),inplace=True)
new_train_set['reanalysis_precip_amt_kg_per_m2'].fillna(new_train_set['reanalysis_precip_amt_kg_per_m2'].mean(),inplace=True)
new_train_set['reanalysis_sat_precip_amt_mm'].fillna(new_train_set['reanalysis_sat_precip_amt_mm'].mean(),inplace=True)
new_train_set['reanalysis_specific_humidity_g_per_kg'].fillna(new_train_set['reanalysis_specific_humidity_g_per_kg'].mean(),inplace=True)
new_train_set['station_avg_temp_c'].fillna(new_train_set['station_avg_temp_c'].mean(),inplace=True)
new_train_set['station_min_temp_c'].fillna(new_train_set['station_min_temp_c'].mean(),inplace=True)
new_train_set['station_max_temp_c'].fillna(new_train_set['station_max_temp_c'].mean(),inplace=True)
new_train_set['station_precip_mm'].fillna(new_train_set['station_precip_mm'].mean(),inplace=True)
new_train_set['precipitation_amt_mm'].fillna(new_train_set['precipitation_amt_mm'].mean(),inplace=True)
new_train_set['reanalysis_relative_humidity_percent'].fillna(new_train_set['reanalysis_relative_humidity_percent'].mean(),inplace=True)


# fill nul values with the next value
new_train_set['ndvi_nw'].fillna(new_train_set['ndvi_nw'].mean(),inplace=True)
new_train_set['ndvi_se'].fillna(new_train_set['ndvi_se'].mean(),inplace=True)
new_train_set['ndvi_sw'].fillna(new_train_set['ndvi_sw'].mean(),inplace=True)
new_train_set['ndvi_ne'].fillna(new_train_set['ndvi_ne'].mean(),inplace=True)

# %%
new_train_set.isnull().sum()
# Out:
# city                                     0
# year                                     0
# weekofyear                               0
# week_start_date                          0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# station_min_temp_c                       0
# station_precip_mm                        0
# total_cases                              0
# dtype: int64

# %%
# plot san juan
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)
sj_corr_heat = sns.heatmap(corr_matrix, ax=ax)
plt.title('corr_matrix')
# Out:
# Text(0.5, 1, 'corr_matrix')

# %%
# San Juan
(corr_matrix
     .total_cases
     .drop('total_cases') # don't compare with myself
     .sort_values(ascending=False)
     .plot
     .barh())

# %% [markdown]
# The wetter the better</br>
# The correlation strengths differ for each city, but it looks like reanalysis_specific_humidity_g_per_kg and reanalysis_dew_point_temp_k are the most strongly correlated with total_cases. This makes sense: we know mosquitos thrive wet climates, the wetter the better!

# %%
# Climate features


# NOAA's NCEP Climate Forecast System Reanalysis measurements (0.5x0.5 degree scale)

# reanalysis_sat_precip_amt_mm – Total precipitation
# reanalysis_dew_point_temp_k – Mean dew point temperature
# reanalysis_air_temp_k – Mean air temperature
# reanalysis_relative_humidity_percent – Mean relative humidity
# reanalysis_specific_humidity_g_per_kg – Mean specific humidity
# reanalysis_precip_amt_kg_per_m2 – Total precipitation
# reanalysis_max_air_temp_k – Maximum air temperature
# reanalysis_min_air_temp_k – Minimum air temperature
# reanalysis_avg_temp_k – Average air temperature
# reanalysis_tdtr_k – Diurnal temperature range

Reanalysis_measurements = ['reanalysis_sat_precip_amt_mm','reanalysis_dew_point_temp_k','reanalysis_air_temp_k',
                                         'reanalysis_relative_humidity_percent','reanalysis_specific_humidity_g_per_kg',
                                        'reanalysis_precip_amt_kg_per_m2','reanalysis_max_air_temp_k','reanalysis_min_air_temp_k',
                                        'reanalysis_avg_temp_k','reanalysis_tdtr_k']

Reanalysis_measurements_df=[Reanalysis_measurements]
plt.scatter(x=new_train_set["reanalysis_dew_point_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_dew_point_temp_k')
plt.ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
plt.figure()
plt.subplot(221)
plt.scatter(x=new_train_set["reanalysis_dew_point_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_dew_point_temp_k')
plt.ylabel('total_cases')


plt.subplot(222)
plt.scatter(x=new_train_set["reanalysis_specific_humidity_g_per_kg"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_specific_humidity_g_per_kg')
plt.ylabel('total_cases')


plt.subplot(223)
plt.scatter(x=new_train_set["reanalysis_sat_precip_amt_mm"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_sat_precip_amt_mm')
plt.ylabel('total_cases')


plt.subplot(224)
plt.scatter(x=new_train_set["reanalysis_dew_point_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_dew_point_temp_k')
plt.ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
plt.figure()
plt.subplot(221)
plt.scatter(x=new_train_set["reanalysis_min_air_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_min_air_temp_k')
plt.ylabel('total_cases')


plt.subplot(222)
plt.scatter(x=new_train_set["reanalysis_specific_humidity_g_per_kg"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_specific_humidity_g_per_kg')
plt.ylabel('total_cases')


plt.subplot(223)
plt.scatter(x=new_train_set["reanalysis_sat_precip_amt_mm"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_sat_precip_amt_mm')
plt.ylabel('total_cases')


plt.subplot(224)
plt.scatter(x=new_train_set["reanalysis_dew_point_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_dew_point_temp_k')
plt.ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
plt.subplot(221)
plt.scatter(x=new_train_set["reanalysis_air_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_air_temp_k')
plt.ylabel('total_cases')


plt.subplot(222)
plt.scatter(x=new_train_set["reanalysis_avg_temp_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_avg_temp_k')
plt.ylabel('total_cases')


plt.subplot(223)
plt.scatter(x=new_train_set["reanalysis_tdtr_k"], y = new_train_set["total_cases"])
plt.xlabel('reanalysis_tdtr_k')
plt.ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
plt.hist(new_train_set["total_cases"])
# Out:
# (array([1266.,  132.,   26.,   12.,    5.,    3.,    2.,    5.,    3.,
#            2.]),
#  array([  0. ,  46.1,  92.2, 138.3, 184.4, 230.5, 276.6, 322.7, 368.8,
#         414.9, 461. ]),
#  <a list of 10 Patch objects>)

# %%
sns.barplot(x='city',y='total_cases',data=new_train_set)

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Convert date to YEAR,MONTH ,DAY

# %%
new_df = new_train_set.copy()

new_df['week_start_date']=pd.to_datetime(new_df['week_start_date'])
new_df['DATE_year']= new_df['week_start_date'].map(lambda x: x.strftime('%Y'))
new_df['DATE_Month']=new_df['week_start_date'].map(lambda x:x.strftime('%B'))
new_df['DATE_Day']=new_df['week_start_date'].map(lambda x:x.strftime('%A'))

# %%
new_df
# Out:
#      city  year  weekofyear  ... DATE_year  DATE_Month  DATE_Day
# 0      sj  1990          18  ...      1990       April    Monday
# 1      sj  1990          19  ...      1990         May    Monday
# 2      sj  1990          20  ...      1990         May    Monday
# 3      sj  1990          21  ...      1990         May    Monday
# 4      sj  1990          22  ...      1990         May    Monday
# ...   ...   ...         ...  ...       ...         ...       ...
# 1451   iq  2010          21  ...      2010         May    Friday
# 1452   iq  2010          22  ...      2010        June    Friday
# 1453   iq  2010          23  ...      2010        June    Friday
# 1454   iq  2010          24  ...      2010        June    Friday
# 1455   iq  2010          25  ...      2010        June    Friday
#
# [1456 rows x 28 columns]

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (4.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)

# %%
import plotly.express as px
# new_df_sj = new_df.loc[new_df['city']== 'sj', ['DATE_Month','total_cases','year','city']]
new_df_sj = new_df.copy()
fig = px.bar(new_df_sj,
             y="DATE_Month",
             x="total_cases",
             animation_frame="year",
             orientation='h',
             range_x=[0, new_df_sj.total_cases.max()],
             color="DATE_Month")
# improve aesthetics (size, grids etc.)
fig.update_layout(width=1200,
                  height=800,
                  xaxis_showgrid=False,
                  yaxis_showgrid=False,
                  paper_bgcolor='rgba(0,0,0,0)',
                  plot_bgcolor='rgba(0,0,0,0)',
                  title_text='Evolution of Natural Disasters',
                  showlegend=False)
fig.update_xaxes(title_text='total_cases of Disease')
fig.update_yaxes(title_text='')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7bf354e7-626c-490b-9f35-8cab540f23e9" class="plotly-graph-div" style="height:800px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7bf354e7-626c-490b-9f35-8cab540f23e9")) {
#                     Plotly.newPlot(
#                         '7bf354e7-626c-490b-9f35-8cab540f23e9',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=April", "marker": {"color": "#636efa"}, "name": "DATE_Month=April", "offsetgroup": "DATE_Month=April", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [4], "xaxis": "x", "y": ["April"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=May", "marker": {"color": "#EF553B"}, "name": "DATE_Month=May", "offsetgroup": "DATE_Month=May", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [5, 4, 3, 6], "xaxis": "x", "y": ["May", "May", "May", "May"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=June", "marker": {"color": "#00cc96"}, "name": "DATE_Month=June", "offsetgroup": "DATE_Month=June", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2, 4, 5, 10], "xaxis": "x", "y": ["June", "June", "June", "June"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=July", "marker": {"color": "#ab63fa"}, "name": "DATE_Month=July", "offsetgroup": "DATE_Month=July", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [6, 8, 2, 6, 17], "xaxis": "x", "y": ["July", "July", "July", "July", "July"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=August", "marker": {"color": "#FFA15A"}, "name": "DATE_Month=August", "offsetgroup": "DATE_Month=August", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [23, 13, 21, 28], "xaxis": "x", "y": ["August", "August", "August", "August"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=September", "marker": {"color": "#19d3f3"}, "name": "DATE_Month=September", "offsetgroup": "DATE_Month=September", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [24, 20, 40, 27], "xaxis": "x", "y": ["September", "September", "September", "September"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=October", "marker": {"color": "#FF6692"}, "name": "DATE_Month=October", "offsetgroup": "DATE_Month=October", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [42, 33, 43, 37, 57], "xaxis": "x", "y": ["October", "October", "October", "October", "October"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=November", "marker": {"color": "#B6E880"}, "name": "DATE_Month=November", "offsetgroup": "DATE_Month=November", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [71, 44, 56, 53], "xaxis": "x", "y": ["November", "November", "November", "November"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "DATE_Month=%{y}<br>year=1990<br>total_cases=%{x}", "legendgroup": "DATE_Month=December", "marker": {"color": "#FF97FF"}, "name": "DATE_Month=December", "offsetgroup": "DATE_Month=December", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [52, 47, 26, 27], "xaxis": "x", "y": ["December", "December", "December", "December"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 800, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "rgba(0,0,0,0)", "plot_bgcolor": "rgba(0,0,0,0)", "showlegend": false, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1993", "method": "animate"}, {"args": [["1994"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1994", "method": "animate"}, {"args": [["1995"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1995", "method": "animate"}, {"args": [["1996"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1996", "method": "animate"}, {"args": [["1997"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1997", "method": "animate"}, {"args": [["1998"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1998", "method": "animate"}, {"args": [["1999"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1999", "method": "animate"}, {"args": [["2000"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2000", "method": "animate"}, {"args": [["2001"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2001", "method": "animate"}, {"args": [["2002"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2002", "method": "animate"}, {"args": [["2003"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2003", "method": "animate"}, {"args": [["2004"], {"frame": {"d

# %%
import plotly.express as px
# df = px.data.gapminder()
df = new_df.copy()
fig = px.scatter(
    df,
    x="reanalysis_air_temp_k",
    y="total_cases",
    animation_frame="year",
    size="total_cases",
    color="DATE_Month",
    hover_name="city",
    log_x=True,
    size_max=70,
    # range_x=[1990, 2010],
    range_x=[df.reanalysis_air_temp_k.min(),df.reanalysis_air_temp_k.max()],
    range_y=[df.total_cases.min(), df.total_cases.max()]
    # range_y=[0, df.total_cases.max()],

    #   color_continuous_scale=px.colors.sequential.Emrld
)
fig.update_layout(width=1000,
                  height=800,
                  xaxis_showgrid=False,
                  yaxis_showgrid=False,
                  paper_bgcolor='rgba(0,0,0,0)',
                  plot_bgcolor='rgba(0,0,0,0)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be194452-9b3c-4568-9847-cb009f2a306a" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be194452-9b3c-4568-9847-cb009f2a306a")) {
#                     Plotly.newPlot(
#                         'be194452-9b3c-4568-9847-cb009f2a306a',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=April<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj"], "legendgroup": "DATE_Month=April", "marker": {"color": "#636efa", "size": [4], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=April", "showlegend": true, "type": "scatter", "x": [297.57285714299996], "xaxis": "x", "y": [4], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=May<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj", "sj", "sj", "sj"], "legendgroup": "DATE_Month=May", "marker": {"color": "#EF553B", "size": [5, 4, 3, 6], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=May", "showlegend": true, "type": "scatter", "x": [298.211428571, 298.781428571, 298.987142857, 299.518571429], "xaxis": "x", "y": [5, 4, 3, 6], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=June<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj", "sj", "sj", "sj"], "legendgroup": "DATE_Month=June", "marker": {"color": "#00cc96", "size": [2, 4, 5, 10], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=June", "showlegend": true, "type": "scatter", "x": [299.63, 299.207142857, 299.591428571, 299.578571429], "xaxis": "x", "y": [2, 4, 5, 10], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=July<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj", "sj", "sj", "sj", "sj"], "legendgroup": "DATE_Month=July", "marker": {"color": "#ab63fa", "size": [6, 8, 2, 6, 17], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=July", "showlegend": true, "type": "scatter", "x": [300.154285714, 299.512857143, 299.667142857, 299.55857142900004, 299.862857143], "xaxis": "x", "y": [6, 8, 2, 6, 17], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=August<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj", "sj", "sj", "sj"], "legendgroup": "DATE_Month=August", "marker": {"color": "#FFA15A", "size": [23, 13, 21, 28], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=August", "showlegend": true, "type": "scatter", "x": [300.391428571, 299.958571429, 300.332857143, 300.11857142900004], "xaxis": "x", "y": [23, 13, 21, 28], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=September<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj", "sj", "sj", "sj"], "legendgroup": "DATE_Month=September", "marker": {"color": "#19d3f3", "size": [24, 20, 40, 27], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=September", "showlegend": true, "type": "scatter", "x": [300.53, 300.674285714, 299.857142857, 300.42714285700004], "xaxis": "x", "y": [24, 20, 40, 27], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DATE_Month=October<br>year=1990<br>reanalysis_air_temp_k=%{x}<br>total_cases=%{marker.size}", "hovertext": ["sj", "sj", "sj", "sj", "sj"], "legendgroup": "DATE_Month=October", "marker": {"color": "#FF6692", "size": [42, 33, 43, 37, 57], "sizemode": "area", "sizeref": 0.09408163265306123, "symbol": "circle"}, "mode": "markers", "name": "DATE_Month=October", "showlegend": true, "type": "scatter", "x": [300.775714286, 299.857142857, 299.195714286, 298.902857143, 299.727142857], "xaxis":  ...
#                         {"height": 800, "legend": {"itemsizing": "constant", "tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "rgba(0,0,0,0)", "plot_bgcolor": "rgba(0,0,0,0)", "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1990"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1993", "method": "animate"}, {"args": [["1994"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1994", "method": "animate"}, {"args": [["1995"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1995", "method": "animate"}, {"args": [["1996"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1996", "method": "animate"}, {"args": [["1997"], {"frame": {"duration": 0, "redraw": false}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label"

# %%
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import pandas as pd
# df = px.data.tips()
fig = go.Figure(go.Sunburst(
    labels=["sj", "iq", "April", "May","June", "July","August","September","October","November","December",'April', 'May', 'June ', 'July ','August','September','October','November','December'],
    parents=["", "", "sj", "sj","sj","sj","sj","sj","sj","sj","sj", 'iq', 'iq','iq', 'iq','iq', 'iq','iq', 'iq','iq'],
    values=np.append(
        new_df.groupby('total_cases').mean().values,
        new_df.groupby('total_cases').mean().values),
    marker=dict(colors=px.colors.sequential.Emrld)),
                layout=go.Layout(paper_bgcolor='rgba(0,0,0,0)',
                                 plot_bgcolor='rgba(0,0,0,0)'))

fig.update_layout(margin=dict(t=0, l=0, r=0, b=0),
                  title_text='Tipping Habbits Per Gender, Time and Day')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4745b355-358b-4094-9b66-9578cbfb5a26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4745b355-358b-4094-9b66-9578cbfb5a26")) {
#                     Plotly.newPlot(
#                         '4745b355-358b-4094-9b66-9578cbfb5a26',
#                         [{"labels": ["sj", "iq", "April", "May", "June", "July", "August", "September", "October", "November", "December", "April", "May", "June ", "July ", "August", "September", "October", "November", "December"], "marker": {"colors": ["rgb(211, 242, 163)", "rgb(151, 225, 150)", "rgb(108, 192, 139)", "rgb(76, 155, 130)", "rgb(33, 122, 121)", "rgb(16, 89, 101)", "rgb(7, 64, 80)"]}, "parents": ["", "", "sj", "sj", "sj", "sj", "sj", "sj", "sj", "sj", "sj", "iq", "iq", "iq", "iq", "iq", "iq", "iq", "iq", "iq"], "type": "sunburst", "values": [2002.29, 29.17, 0.2607622539999999, 0.23425742929999988, 0.25692216139999996, 0.2715137983, 55.73030388080389, 297.85505714289, 299.12025577947037, 294.64912070739297, 307.48527109266945, 292.4331915629325, 43.593818188105125, 84.62901959098889, 55.73030388080389, 16.208349980240342, 9.930285714285604, 27.245522884441094, 10.769185714285797, 33.847146239554334, 20.62008599167823, 48.967054393305425, 2004.5593220338983, 25.983050847457626, 0.19990631016949148, 0.18244355835593218, 0.22855375610169495, 0.23327900847457625, 59.64407437424387, 297.74866828089824, 298.6753729918309, 295.09528933449644, 305.48181541130407, 293.4376128185292, 54.79240370865274, 87.00223659489815, 59.64407437424387, 16.636041128744655, 7.525181598063219, 27.136771067346945, 9.380460048426782, 33.1441504178273, 21.505121182914504, 52.317842706191044, 2003.9130434782608, 26.55072463768116, 0.22150467149275363, 0.19641954550724638, 0.24473160579710135, 0.24415490043478255, 50.433043478260856, 298.2077225673189, 299.1001035196086, 295.1584472049855, 305.10869565217394, 294.24347826086955, 44.120144927536245, 84.74430641822318, 50.433043478260856, 16.707991718426086, 7.063975155282029, 27.35385783299129, 9.3225810904058, 33.13478260869565, 21.698550724637695, 39.87574434540052, 2004.0857142857142, 24.142857142857142, 0.16746600957142863, 0.15162486428571423, 0.21116898314285706, 0.20901823414285714, 51.612999999999985, 298.1161224489998, 298.79418367352855, 294.78353061228563, 304.0414285714286, 294.3542857142857, 33.514, 83.00030612244859, 51.612999999999985, 16.29742857143143, 6.167551020409284, 27.078304254470698, 8.451156462585574, 32.46149820931158, 21.654285714285713, 49.02789599521818, 2002.875, 24.821428571428573, 0.16202861482142855, 0.1754441216607143, 0.21815786071428564, 0.21652805714285717, 52.29286407286407, 298.5450255101964, 299.2415281776791, 295.37679718154084, 304.5004840940525, 295.07355636237907, 41.903961050187704, 83.59651457574452, 52.29286407286407, 16.90386476063812, 5.926785714283929, 27.3944734721582, 8.785510204081607, 33.06165066653403, 21.93218124628492, 46.0522564255828, 2004.2714285714285, 24.428571428571427, 0.16901346324285718, 0.16730766757142862, 0.22610065414285718, 0.23419759299999998, 52.75742857142857, 298.3861224489857, 299.3018367346713, 295.37532653061425, 305.16428571428577, 294.43285714285713, 40.027999999999984, 84.94314285713428, 52.75742857142857, 16.909163265304286, 7.055510204080571, 27.374335307229718, 9.300408163261855, 33.43142857142857, 21.565714285714282, 44.95751942618052, 2002.7887323943662, 25.12676056338028, 0.17455209619718312, 0.14290251845070423, 0.2272911112676056, 0.2308424423943662, 49.653098591549295, 298.39010060357737, 299.09678068415485, 295.15098591545063, 304.0943661971831, 294.97464788732384, 38.88507042253522, 83.39372233400142, 49.653098591549295, 16.656961770621127, 5.888128772636479, 27.135454228082395, 8.23199865861831, 32.64440052571697, 21.885915492957746, 49.05915492957746, 2003.0172413793102, 21.413793103448278, 0.11952046603448276, 0.11958664194827584, 0.1914809703448276, 0.19813576793103457, 40.19879310344828, 298.5225123153448, 299.1104679803103, 294.9982019704655, 303.4879310344828, 295.3293103448275, 31.281034482758624, 81.89440886699654, 40.19879310344828, 16.500911330046552, 5.38990147783, 27.004581280786216, 8.31778325123086, 32.27758620689655, 21.92241379310346, 40.41724137931034, 2003.0227272727273, 20.431818181818 ...
